# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import pandas as pd
import numpy as np
import matplotlib
import threading
import matplotlib.pyplot as plt 
import seaborn as sns
from collections import Counter
matplotlib.rcParams['savefig.dpi'] = 200
sys.setrecursionlimit(3000)
import pickle
from sklearn import preprocessing
import time
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
workingDirectory = '/home/h1bennet/lxr/results/181030_dmhca_ip/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# ### Define functions for later...

# %% [markdown]
# ### QC

# %%
rna_qc = ngs_qc('/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/', 'rna')
# Out:
# /home/h1bennet/lxr/data/mouse/RNA/dmhca_ip//
# ./dmhca_ip_qc/
# /home/h1bennet/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
rna_qc
# Out:
#                                                     uniquePositions  \
# C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711C_...        2281519.0
# C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711D_...        3790511.0
# C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712C_...        1775863.0
# C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712D_...        2169701.0
# C57B6J_Microglia_RNA_Veh_12h_C5711A_HBENN_l2018...        3405167.0
# C57B6J_Microglia_RNA_Veh_12h_C5711B_HBENN_l2018...        4942894.0
# C57B6J_Microglia_RNA_Veh_12h_C5712B_HBENN_l2018...        3676397.0
# C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5...        4576710.0
# C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5...        4375288.0
# C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5...        2283019.0
# C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5...        2756919.0
# C57B6J_Tim4PosKupffer_RNA_Veh_12h_C5711A_HBENN_...        4455433.0
# C57B6J_Tim4PosKupffer_RNA_Veh_12h_C5711B_HBENN_...        4830940.0
# ...

# %% [markdown]
# 12B looks like it failed

# %% [markdown]
# ### Aggregate counts

# %%
# %%bash
# # if directories don't exist, create them
# if [ ! -d ./expression/ ]; then mkdir ./expression; fi
#
# analyzeRepeats.pl rna mm10 -count exons -condenseGenes -raw -d /home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/* > ./expression/rna_exp_raw.tsv
# analyzeRepeats.pl rna mm10 -count exons -condenseGenes -rpkm -d /home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/* > ./expression/rna_exp_rpkm.tsv
# analyzeRepeats.pl rna mm10 -count exons -condenseGenes -tpm -d /home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/* > ./expression/rna_exp_tpm.tsv
# Out:
# 	Tag Directories:
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711C_HBENN_l20181012_AGTCAA
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711D_HBENN_l20181012_AGTTCC
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712C_HBENN_l20181012_CCGTCC
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712D_HBENN_l20181012_GTAGAG
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_Veh_12h_C5711A_HBENN_l20181012_TAGCTT
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_Veh_12h_C5711B_HBENN_l20181012_GGCTAC
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Microglia_RNA_Veh_12h_C5712B_HBENN_l20181012_ATGTCA
# 		/home/h1bennet/lxr/data/mouse/RNA/dmhca_ip/C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5711C_HBENN_l20181012_ACAGTG
# ...

# %% [markdown]
# ### Summary plots (PCA, heatmap)

# %%
# read in rpkm
rpkm = pd.read_csv('./expression/rna_exp_rpkm.tsv', sep='\t')
rpkm.set_index(rpkm.columns.values[0], inplace=True)
rpkm.index.rename('refseqID', inplace=True)
# set rpkm index
mm10_gene = rpkm['Annotation/Divergence'].str.split('|').str[0]

# clean up column names
# rename rpkm columns
rpkm = rpkm.rename(columns=dict(zip(rpkm.iloc[:, 7:].columns.values,
                                    pd.Series(rpkm.iloc[:, 7:].columns.values).str[:-5].str.split('/').str[-1])))
# change index to gene names
rpkm['gene'] = mm10_gene
rpkm = rpkm.reset_index().set_index('gene').drop(labels='refseqID', axis=1)

# filter genes with length < 250 bp
rpkm = rpkm.loc[rpkm.Length >= 250, :]

# %%
ax = plt.scatter(rpkm.iloc[:, 7:].mean(), rpkm.iloc[:, 7:].var())
plt.xlabel('sample rpkm mean')
plt.ylabel('sample rpkm variance')
label_point(rpkm.iloc[:, 7:].mean(),
            rpkm.iloc[:, 7:].var(),
            pd.Series(rpkm.iloc[:, 7:].columns.values, index=rpkm.iloc[:, 7:].columns.values).str.split('_12h').str[0],
            plt.gca())

# %% [markdown]
# ### PCA plot

# %%
if not os.path.isdir('./figures'):
    os.mkdir('./figures')

# %%
# filter lowly expressed genes
rpkm_filt = rpkm.loc[(rpkm.iloc[:, 7:] > 4).all(1), :]


samples = pd.Series(rpkm.iloc[:, 7:].columns.values)
cage = samples.str.split('_').str[5]
group = samples.str.split('_').str[3]
cell = samples.str.split('_').str[1]

samplesDF = pd.DataFrame([pd.Series(samples),
                          pd.Series(cage),
                          pd.Series(group),
                          pd.Series(gender)],
                          index=['mouse', 'cage', 'group', 'cell']).T

# quantile normalize
rpkm_filt_quant = quantile_normalize_df(rpkm_filt.iloc[:, 7:])

# %%
pca, exp_var, pcs = pca_rpkm_mat(rpkm=rpkm_filt_quant, group_labels=samplesDF.cell+'_'+samplesDF.group)
# label_point(pca.PC1,
#             pca.PC2,
#             samplesDF.cage,
#             plt.gca())
plt.savefig('./figures/rna_pca_filt.pdf')

# %%
pcs.sort_values('PC1', ascending=False).head()
# Out:
#              PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# gene
# Apoe    0.520790 -0.021977  0.086557  0.039432  0.004582 -0.005834 -0.055922
# Tmsb4x  0.196451 -0.035185 -0.263161  0.366156  0.079700  0.029198 -0.096359
# Cd5l    0.173876 -0.000263  0.088429  0.160639  0.036230  0.352156 -0.015842
# Actb    0.171639 -0.031135 -0.335079 -0.101180  0.075571  0.337939  0.121145
# Lyz2    0.155612 -0.024885 -0.098816 -0.046302 -0.009082 -0.223961  0.032111
#
#              PC8       PC9      PC10
# gene
# Apoe    0.005416 -0.033464 -0.044563
# Tmsb4x  0.269604  0.019809  0.119692
# Cd5l   -0.203603 -0.011508  0.343517
# Actb   -0.335222  0.142749 -0.221419
# Lyz2   -0.322630  0.036233 -0.058484

# %%
pcs.sort_values('PC1', ascending=True).head()
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# gene
# Cst3 -0.412418 -0.606066  0.057787  0.037464 -0.155906  0.039495 -0.189512
# Ctsd -0.327631  0.726827 -0.056171 -0.005185  0.098051 -0.009805 -0.085964
# Hexb -0.284359 -0.035833 -0.047645 -0.004827  0.066085  0.032370  0.357755
# Rhob -0.137389  0.024637 -0.012977  0.015383 -0.097685 -0.002258 -0.143046
# Jun  -0.113459 -0.047111  0.028158 -0.033083  0.284984  0.003388 -0.273191
#
#            PC8       PC9      PC10
# gene
# Cst3 -0.113184  0.141160 -0.057158
# Ctsd -0.091638  0.010050 -0.049784
# Hexb  0.143320  0.022652  0.026094
# Rhob -0.069624 -0.062071 -0.049115
# Jun  -0.053843  0.083719  0.015331

# %% [markdown]
# ### Microglia Only

# %%
pca, exp_var, pcs = pca_rpkm_mat(rpkm=rpkm_filt_quant.iloc[:, :7],
                                 group_labels=(samplesDF.cell+'_'+samplesDF.group)[:7])
label_point(pca.PC1,
            pca.PC2,
            samplesDF.cage[:7],
            plt.gca())
plt.savefig('./figures/microglia_dmhca_ip_pca.pdf')

# %% [markdown]
# ### Kupffer only

# %%
samplesDF
# Out:
#                                                 mouse    cage           group  \
# 0   C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711C...  C5711C  DMHCA50mgperkg
# 1   C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711D...  C5711D  DMHCA50mgperkg
# 2   C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712C...  C5712C  DMHCA50mgperkg
# 3   C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712D...  C5712D  DMHCA50mgperkg
# 4   C57B6J_Microglia_RNA_Veh_12h_C5711A_HBENN_l201...  C5711A             Veh
# 5   C57B6J_Microglia_RNA_Veh_12h_C5711B_HBENN_l201...  C5711B             Veh
# 6   C57B6J_Microglia_RNA_Veh_12h_C5712B_HBENN_l201...  C5712B             Veh
# 7   C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C...  C5711C  DMHCA50mgperkg
# 8   C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C...  C5711D  DMHCA50mgperkg
# 9   C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C...  C5712C  DMHCA50mgperkg
# 10  C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C...  C5712D  DMHCA50mgperkg
# ...

# %%
rpkm_filt_quant.columns.tolist()
# Out:
# ['C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711C_HBENN_l20181012_AGTCAA',
#  'C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5711D_HBENN_l20181012_AGTTCC',
#  'C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712C_HBENN_l20181012_CCGTCC',
#  'C57B6J_Microglia_RNA_DMHCA50mgperkg_12h_C5712D_HBENN_l20181012_GTAGAG',
#  'C57B6J_Microglia_RNA_Veh_12h_C5711A_HBENN_l20181012_TAGCTT',
#  'C57B6J_Microglia_RNA_Veh_12h_C5711B_HBENN_l20181012_GGCTAC',
#  'C57B6J_Microglia_RNA_Veh_12h_C5712B_HBENN_l20181012_ATGTCA',
#  'C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5711C_HBENN_l20181012_ACAGTG',
#  'C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5711D_HBENN_l20181012_CAGATC',
#  'C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5712C_HBENN_l20181012_ACTTGA',
#  'C57B6J_Tim4PosKupffer_RNA_DMHCA50mgperkg_12h_C5712D_HBENN_l20181012_GATCAG',
#  'C57B6J_Tim4PosKupffer_RNA_Veh_12h_C5711A_HBENN_l20181012_CGATGT',
#  'C57B6J_Tim4PosKupffer_RNA_Veh_12h_C5711B_HBENN_l20181012_TGACCA',
# ...

# %%
pca.PC1
# Out:
# 0     1.858816
# 1    -5.838644
# 2    -4.977670
# 3    -8.384299
# 4    -0.107890
# 5    -2.059414
# 6    19.509100
# Name: PC1, dtype: float64

# %%
pca.PC2
# Out:
# 0     2.986835
# 1    -4.935871
# 2    -4.485662
# 3    -6.445191
# 4     6.861478
# 5    10.543647
# 6    -4.525237
# Name: PC2, dtype: float64

# %%
samplesDF.cage[-7:]
# Out:
# 7     C5711C
# 8     C5711D
# 9     C5712C
# 10    C5712D
# 11    C5711A
# 12    C5711B
# 13    C5712B
# Name: cage, dtype: object

# %%
pca, exp_var, pcs = pca_rpkm_mat(rpkm=rpkm_filt_quant.iloc[:, 7:],
                                 group_labels=(samplesDF.cell+'_'+samplesDF.group)[7:])
label_point(pca.PC1,
            pca.PC2,
            samplesDF.cage[-7:].reset_index(drop=True),
            plt.gca())
plt.savefig('./figures/kupffer_dmhca_ip_pca.pdf')

# %%
pca, exp_var, pcs = pca_rpkm_mat(rpkm=rpkm_filt_quant.iloc[:, 7:],
                                 group_labels=(samplesDF.cage)[7:])

plt.savefig('./figures/kupffer_dmhca_ip_pca_cage.pdf')

# %% [markdown]
# ### Look at pearson corr between samples

# %%
rpkm_tmp = rpkm_filt.iloc[:, 7:]
rpkm_tmp.columns = samplesDF.cell+'_'+samplesDF.cage

# %%
g = sns.PairGrid(np.log2(rpkm_tmp.iloc[:, :7] + 1), size=2.5)
g = g.map(plt.scatter)
corrs = np.log(rpkm_tmp.iloc[:, :7] + 1).corr().values.flatten()
for ax, corrval in zip(g.axes.flat, corrs):
    ax.text(0, 0, "r = %.2f" % corrval, fontsize=9)
plt.savefig('./figures/microglia_rna_corr_scatter.pdf', bbox_inches='tight')

# %%
g = sns.PairGrid(np.log2(rpkm_tmp.iloc[:, 7:] + 1), size=2.5)
g = g.map(plt.scatter)
corrs = np.log(rpkm_tmp.iloc[:, 7:] + 1).corr().values.flatten()
for ax, corrval in zip(g.axes.flat, corrs):
    ax.text(0, 0, "r = %.2f" % corrval, fontsize=9)
plt.savefig('./figures/kupffer_rna_corr_scatter.pdf', bbox_inches='tight')

# %% [markdown]
# # pearson correlation

# %%
rpkm_corr = rpkm_filt_quant.corr()
rpkm_corr.index = samplesDF.cell+'_'+samplesDF.group+'_'+samplesDF.cage
cm = sns.clustermap(rpkm_corr)
plt.setp(cm.ax_heatmap.yaxis.get_majorticklabels(), rotation=0);
# Out:
# /home/h1bennet/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
